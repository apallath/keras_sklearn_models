# %% [markdown]
# References:
# - Introduction to Data Science (Laura Igual, Santi Segui)
#   (Jupyter notebooks at https://github.com/DataScienceUB/introduction-datascience-python-book)
# - Datacamp tutorial on Pandas
#   (https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
#Dataframe from a Numpy array
arr = np.array([['','C1','C2','C3'],['R1',1,2,3],['R2',4,5,6],['R3',7,8,9],['R4',10,11,12]])
print arr; print
df_arr = pd.DataFrame(data=arr[1:,1:], index=arr[1:,0], columns=arr[0,1:])
print df_arr
print df_arr.shape
print len(df_arr)
# Out:
# [['' 'C1' 'C2' 'C3']
#  ['R1' '1' '2' '3']
#  ['R2' '4' '5' '6']
#  ['R3' '7' '8' '9']
#  ['R4' '10' '11' '12']]
#
#     C1  C2  C3
# R1   1   2   3
# R2   4   5   6
# R3   7   8   9
# R4  10  11  12
# (4, 3)
# 4

# %%
#Dataframe from a Dictionary
d = {'year': [2015,2016,2017,2015,2016,2017,2015,2016,2017],
    'party': ['A','A','A','B','B','B','C','C','C'],
    'number of seats won':np.random.randint(100,size=9)}
df_d = pd.DataFrame(d) #randomly ordered
print df_d
df_do = pd.DataFrame(d, columns=['year','party','number of seats won'])
print df_do
# Out:
#    number of seats won party  year
# 0                    8     A  2015
# 1                   83     A  2016
# 2                    7     A  2017
# 3                    9     B  2015
# 4                   77     B  2016
# 5                   73     B  2017
# 6                   33     C  2015
# 7                   62     C  2016
# 8                   16     C  2017
#    year party  number of seats won
# 0  2015     A                    8
# 1  2016     A                   83
# 2  2017     A                    7
# 3  2015     B                    9
# 4  2016     B                   77
# 5  2017     B                   73
# 6  2015     C                   33
# 7  2016     C                   62
# 8  2017     C                   16

# %%
hicp = pd.read_csv('eurostat_hicp.csv', na_values=':')
#Harmonized Indices of Consumer Prices (HICP) for household equipment
hicp
# Out:
#                                  geo\time  2016M09  2016M10  2016M11  2016M12  \
# 0        Euro area (changing composition)    99.20    99.66    99.72   100.22
# 1                Euro area (19 countries)    99.20    99.66    99.72   100.22
# 2                Euro area (18 countries)    99.21    99.66    99.73   100.23
# 3   European Union (changing composition)    99.39    99.78    99.87   100.26
# 4                       EU (28 countries)    99.39    99.78    99.87   100.26
# 5                                 Belgium   102.41   103.21   103.06   104.33
# 6                                Bulgaria    99.22    99.29    99.28    99.31
# 7                          Czech Republic   100.00   100.10   100.20   100.20
# 8                                 Denmark    99.70   100.00   100.40   100.60
# 9                                 Germany    99.30    99.70    99.60   100.10
# 10                                Estonia    98.49    99.45    99.84    99.08
# ...

# %%
print hicp.head()
print hicp.tail()
# Out:
#                                 geo\time  2016M09  2016M10  2016M11  2016M12  \
# 0       Euro area (changing composition)    99.20    99.66    99.72   100.22
# 1               Euro area (19 countries)    99.20    99.66    99.72   100.22
# 2               Euro area (18 countries)    99.21    99.66    99.73   100.23
# 3  European Union (changing composition)    99.39    99.78    99.87   100.26
# 4                      EU (28 countries)    99.39    99.78    99.87   100.26
#
#    2017M01  2017M02  2017M03  2017M04  2017M05  2017M06  2017M07  2017M08
# 0   100.94   100.81   100.73   100.82   100.66   100.64   100.59   100.73
# 1   100.94   100.81   100.73   100.82   100.66   100.64   100.59   100.73
# 2   100.95   100.82   100.74   100.82   100.67   100.64   100.59   100.73
# 3   100.86   100.79   100.75   100.86   100.82   100.80   100.85   100.99
# 4   100.86   100.79   100.75   100.86   100.82   100.80   100.85   100.99
# ...

# %%
hicp.describe()
# Out:
#           2016M09     2016M10     2016M11     2016M12     2017M01     2017M02  \
# count   39.000000   39.000000   39.000000   39.000000   39.000000   39.000000
# mean    99.925385  100.399231  100.663333  100.927436  101.356923  101.537179
# std      2.726305    2.877521    3.309952    3.027898    3.460126    3.580219
# min     94.750000   95.290000   96.010000   97.590000   94.270000   94.320000
# 25%     98.495000   98.880000   98.975000   99.380000  100.000000   99.940000
# 50%     99.550000   99.780000   99.870000  100.220000  100.860000  100.810000
# 75%    101.415000  101.280000  101.350000  101.560000  102.235000  101.800000
# max    107.900000  111.500000  115.200000  112.800000  113.300000  113.700000
#
#           2017M03     2017M04     2017M05     2017M06     2017M07     2017M08
# count   39.000000   39.000000   39.000000   39.000000   39.000000   38.000000
# mean   101.560769  101.584103  101.511795  101.568462  101.724872  101.596316
# ...

# %%
hicp['2017M05']
# Out:
# 0     100.66
# 1     100.66
# 2     100.67
# 3     100.82
# 4     100.82
# 5     105.34
# 6     101.30
# 7     100.40
# 8     100.80
# 9     100.50
# 10     99.45
# 11    103.20
# 12     98.99
# 13     98.51
# 14    101.31
# 15     93.49
# 16    100.30
# 17    100.12
# 18     98.83
# 19     98.20
# 20     99.68
# 21    101.34
# 22    101.63
# 23    100.11
# 24    102.20
# 25    101.10
# 26    100.92
# 27     98.61
# 28    101.38
# 29     96.19
# 30    104.01
# 31    102.93
# 32    102.00
# 33    105.92
# 34    112.90
# 35    100.82
# 36    103.90
# 37    113.86
# 38    105.09
# Name: 2017M05, dtype: float64

# %%
hicp.ix[[5,33],['2017M01','2017M08']]
# Out:
# /home/akash/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#     2017M01  2017M08
# 5    105.77   105.38
# 33   105.78   106.92

# %%
hicp[5:38] #from 5 to 37
# Out:
#           geo\time  2016M09  2016M10  2016M11  2016M12  2017M01  2017M02  \
# 5          Belgium   102.41   103.21   103.06   104.33   105.77   106.29
# 6         Bulgaria    99.22    99.29    99.28    99.31    99.69    99.83
# 7   Czech Republic   100.00   100.10   100.20   100.20   100.70   100.30
# 8          Denmark    99.70   100.00   100.40   100.60   100.60   101.50
# 9          Germany    99.30    99.70    99.60   100.10   100.40   100.50
# 10         Estonia    98.49    99.45    99.84    99.08    99.96    99.98
# 11         Ireland   101.60   102.20   102.00   102.70   102.90   103.30
# 12          Greece    96.26    98.58    98.35    99.11    99.64    99.72
# 13           Spain    95.93    97.94    98.59    99.88   102.67    99.65
# 14          France    99.90   100.09   100.33   100.73   101.56   101.58
# 15         Croatia    97.04    97.21    97.24    97.62    94.27    94.32
# 16           Italy    98.30    98.40    98.50    98.60    99.40    99.90
# ...

# %%
hicp.loc[5:37] #from 5 to 37
# Out:
#           geo\time  2016M09  2016M10  2016M11  2016M12  2017M01  2017M02  \
# 5          Belgium   102.41   103.21   103.06   104.33   105.77   106.29
# 6         Bulgaria    99.22    99.29    99.28    99.31    99.69    99.83
# 7   Czech Republic   100.00   100.10   100.20   100.20   100.70   100.30
# 8          Denmark    99.70   100.00   100.40   100.60   100.60   101.50
# 9          Germany    99.30    99.70    99.60   100.10   100.40   100.50
# 10         Estonia    98.49    99.45    99.84    99.08    99.96    99.98
# 11         Ireland   101.60   102.20   102.00   102.70   102.90   103.30
# 12          Greece    96.26    98.58    98.35    99.11    99.64    99.72
# 13           Spain    95.93    97.94    98.59    99.88   102.67    99.65
# 14          France    99.90   100.09   100.33   100.73   101.56   101.58
# 15         Croatia    97.04    97.21    97.24    97.62    94.27    94.32
# 16           Italy    98.30    98.40    98.50    98.60    99.40    99.90
# ...

# %%
#boolean indexing
hicp[hicp['2017M08']>102]
hicp[hicp['2017M08']>102].loc[5:37] #only select values from indices 5 to 37
# Out:
#           geo\time  2016M09  2016M10  2016M11  2016M12  2017M01  2017M02  \
# 5          Belgium   102.41   103.21   103.06   104.33   105.77   106.29
# 6         Bulgaria    99.22    99.29    99.28    99.31    99.69    99.83
# 10         Estonia    98.49    99.45    99.84    99.08    99.96    99.98
# 11         Ireland   101.60   102.20   102.00   102.70   102.90   103.30
# 22           Malta   101.46   101.06   101.13   101.13   101.24   101.25
# 24         Austria   101.37   101.50   101.57   101.99   101.80   102.02
# 30         Finland   102.11   102.56   102.51   102.90   103.51   103.64
# 31          Sweden   101.59   102.58   103.75   103.02   103.74   103.77
# 32  United Kingdom   100.30   100.50   100.50   100.70   100.80   100.90
# 33         Iceland   104.23   104.19   104.55   104.72   105.78   105.84
# 34          Norway   107.90   111.50   115.20   112.80   113.30   113.70
# 36          Serbia   101.70   103.20   103.50   103.70   103.90   105.10
#
# ...

# %%
hicp[hicp['2017M08'].isnull()] #finding NaN values
# Out:
#    geo\time  2016M09  2016M10  2016M11  2016M12  2017M01  2017M02  2017M03  \
# 37   Turkey   107.66   107.41   108.34   109.36   111.36   112.67   113.16
#
#     2017M04  2017M05  2017M06  2017M07  2017M08
# 37    113.4   113.86   114.21   114.72      NaN

# %%
hicp[5:38].max(axis = 0, numeric_only=True) #maximum of every column, over rows
# Out:
# 2016M09    107.90
# 2016M10    111.50
# 2016M11    115.20
# 2016M12    112.80
# 2017M01    113.30
# 2017M02    113.70
# 2017M03    113.50
# 2017M04    113.40
# 2017M05    113.86
# 2017M06    114.21
# 2017M07    114.72
# 2017M08    112.40
# dtype: float64

# %%
hicp[5:38].max(axis = 1, numeric_only=True)
# Out:
# 5     106.50
# 6     102.33
# 7     100.70
# 8     101.70
# 9     100.60
# 10    102.42
# 11    104.40
# 12     99.72
# 13    102.67
# 14    101.74
# 15     97.62
# 16    100.30
# 17    101.41
# 18     99.31
# 19    100.19
# 20    100.16
# 21    101.78
# 22    102.58
# 23    101.12
# 24    102.54
# 25    101.40
# 26    101.18
# 27    100.32
# 28    101.52
# 29     98.20
# 30    104.61
# 31    104.16
# 32    102.40
# 33    106.92
# 34    115.20
# 35    101.16
# 36    105.10
# 37    114.72
# dtype: float64

# %%
s = hicp['2017M08']/hicp['2017M08'].max() * 100
s #generate Pandas series
# Out:
# 0      89.617438
# 1      89.617438
# 2      89.617438
# 3      89.848754
# 4      89.848754
# 5      93.754448
# 6      91.040925
# 7      89.412811
# 8      89.501779
# 9      89.501779
# 10     91.120996
# 11     92.882562
# 12     87.322064
# 13     87.793594
# 14     89.937722
# 15     83.256228
# 16     88.967972
# 17     88.104982
# 18     88.354093
# 19     89.137011
# 20     88.701068
# 21     90.551601
# 22     91.263345
# 23     89.937722
# 24     91.227758
# 25     90.213523
# 26     89.590747
# 27     89.252669
# 28     90.142349
# 29     85.587189
# 30     93.069395
# 31     92.669039
# 32     91.103203
# 33     95.124555
# 34    100.000000
# 35     90.000000
# 36     92.704626
# 37           NaN
# 38     94.973310
# Name: 2017M08, dtype: float64

# %%
import copy
hicpperc = copy.deepcopy(hicp)
for col in hicp.columns[1:]:
    hicpperc[col] = hicpperc[col]/hicp[col].max() * 100
hicpperc
# Out:
#                                  geo\time     2016M09     2016M10     2016M11  \
# 0        Euro area (changing composition)   91.936979   89.381166   86.562500
# 1                Euro area (19 countries)   91.936979   89.381166   86.562500
# 2                Euro area (18 countries)   91.946247   89.381166   86.571181
# 3   European Union (changing composition)   92.113068   89.488789   86.692708
# 4                       EU (28 countries)   92.113068   89.488789   86.692708
# 5                                 Belgium   94.911956   92.565022   89.461806
# 6                                Bulgaria   91.955514   89.049327   86.180556
# 7                          Czech Republic   92.678406   89.775785   86.979167
# 8                                 Denmark   92.400371   89.686099   87.152778
# 9                                 Germany   92.029657   89.417040   86.458333
# 10                                Estonia   91.278962   89.192825   86.666667
# ...

# %%
for col in hicp.columns[1:]:
    ser = hicp[col].apply(lambda x: x/100)

# %%
hicp_no_usa = hicp.drop(38)
newhicp = hicp_no_usa.dropna()
newhicp
# Out:
#                                  geo\time  2016M09  2016M10  2016M11  2016M12  \
# 0        Euro area (changing composition)    99.20    99.66    99.72   100.22
# 1                Euro area (19 countries)    99.20    99.66    99.72   100.22
# 2                Euro area (18 countries)    99.21    99.66    99.73   100.23
# 3   European Union (changing composition)    99.39    99.78    99.87   100.26
# 4                       EU (28 countries)    99.39    99.78    99.87   100.26
# 5                                 Belgium   102.41   103.21   103.06   104.33
# 6                                Bulgaria    99.22    99.29    99.28    99.31
# 7                          Czech Republic   100.00   100.10   100.20   100.20
# 8                                 Denmark    99.70   100.00   100.40   100.60
# 9                                 Germany    99.30    99.70    99.60   100.10
# 10                                Estonia    98.49    99.45    99.84    99.08
# ...

# %%
#Sorting
#inplace => sorting takes place in the current DataFrame
hicp.sort_values(by='2017M07', inplace=True)
hicp
# Out:
#                                  geo\time  2016M09  2016M10  2016M11  2016M12  \
# 15                                Croatia    97.04    97.21    97.24    97.62
# 29                               Slovakia    98.13    98.17    98.19    98.20
# 12                                 Greece    96.26    98.58    98.35    99.11
# 13                                  Spain    95.93    97.94    98.59    99.88
# 17                                 Cyprus    94.75    95.29    96.01    97.59
# 18                                 Latvia    97.35    97.38    97.15    97.84
# 20                             Luxembourg    98.50    98.80    98.67    99.45
# 16                                  Italy    98.30    98.40    98.50    98.60
# 19                              Lithuania    96.66    97.28    98.03    97.78
# 27                                Romania    97.21    97.75    97.81    97.90
# 7                          Czech Republic   100.00   100.10   100.20   100.20
# ...

# %%
hicp.sort_index(inplace=True)
hicpplt = hicp.drop(range(0,5), axis=0)
hicpplt = hicpplt.set_index(['geo\\time'])
hicpplt
# Out:
#                 2016M09  2016M10  2016M11  2016M12  2017M01  2017M02  2017M03  \
# geo\time
# Belgium          102.41   103.21   103.06   104.33   105.77   106.29   106.50
# Bulgaria          99.22    99.29    99.28    99.31    99.69    99.83    99.77
# Czech Republic   100.00   100.10   100.20   100.20   100.70   100.30   100.30
# Denmark           99.70   100.00   100.40   100.60   100.60   101.50   101.70
# Germany           99.30    99.70    99.60   100.10   100.40   100.50   100.40
# Estonia           98.49    99.45    99.84    99.08    99.96    99.98    99.04
# Ireland          101.60   102.20   102.00   102.70   102.90   103.30   103.20
# Greece            96.26    98.58    98.35    99.11    99.64    99.72    99.45
# Spain             95.93    97.94    98.59    99.88   102.67    99.65    98.15
# France            99.90   100.09   100.33   100.73   101.56   101.58   101.74
# Croatia           97.04    97.21    97.24    97.62    94.27    94.32    94.01
# ...

# %%
mean = hicpplt.mean(axis = 1)
mean.plot(kind='bar')
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(10, 10, forward=True)

# %%
hicpplt.iloc[:,1:4].plot(kind='bar')
#for getting a bigger figure
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5, forward=True) #forward propagates the changes to the already existing figure
